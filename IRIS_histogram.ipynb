# %% [markdown]
# <a href="https://colab.research.google.com/github/muthu173cyber/Python-Projects/blob/main/IRIS_histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("setup complete")
# Out:
# setup complete

# %%
iris_filepath = "/content/iris1.csv"
iris_data = pd.read_csv(iris_filepath)

# %%
iris_data.head(10)
# Out:
#    Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0   1                5.1               3.5                1.4
# 1   2                4.9               3.0                1.4
# 2   3                4.7               3.2                1.3
# 3   4                4.6               3.1                1.5
# 4   5                5.0               3.6                1.4
# 5   6                5.4               3.9                1.7
# 6   7                4.6               3.4                1.4
# 7   8                5.0               3.4                1.5
# 8   9                4.4               2.9                1.4
# 9  10                4.9               3.1                1.5
#
#    Petal Width (cm)      Species
# 0               0.2  Iris-setosa
# 1               0.2  Iris-setosa
# 2               0.2  Iris-setosa
# 3               0.2  Iris-setosa
# 4               0.2  Iris-setosa
# 5               0.4  Iris-setosa
# 6               0.3  Iris-setosa
# ...

# %%
#histograms
sns.histplot(iris_data['Petal Length (cm)'])
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Count'>

# %%
#denstity plot
sns.kdeplot(data=iris_data['Petal Length (cm)'],shade=True)
# Out:
# <ipython-input-10-12a7ee6762ca>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris_data['Petal Length (cm)'],shade=True)
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>

# %%
#2D KDE plot
sns.jointplot(x=iris_data['Petal Length (cm)'],y=iris_data['Sepal Width (cm)'],kind="kde")

# %%
#color coded plots
sns.histplot(data=iris_data,x='Petal Length (cm)',hue='Species')
plt.title("Histogram of Petal Lengths,by Species")
# Out:
# Text(0.5, 1.0, 'Histogram of Petal Lengths,by Species')

# %%
sns.kdeplot(data=iris_data,x='Petal Length (cm)',hue='Species',shade=True)
plt.title("Distirbution of Petal Length by Species")
# Out:
# <ipython-input-17-32053c08d90c>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris_data,x='Petal Length (cm)',hue='Species',shade=True)
# Text(0.5, 1.0, 'Distirbution of Petal Length by Species')
